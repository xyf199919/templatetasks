# %%
import os

try:
  dbutils.fs.mount("s3a://bd-databricks-less-limited-shard-kjbhdfkljbnkjbdfkjbalkdnvubhbv/sequenceddata.csv")
except:
  pass

# %%
import pandas as pd
import pprint
import math
pp = pprint.PrettyPrinter(indent = 4)

#read from csv (TODO change this file to updated version)
df = pd.read_csv('s3a://bd-databricks-less-limited-shard-kjbhdfkljbnkjbdfkjbalkdnvubhbv/sequence_categoryok.csv')

columnlist = df.columns.tolist()

df
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/s3.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode)
#      29     try:
# ---> 30         filepath_or_buffer = fs.open(_strip_schema(filepath_or_buffer), mode)
#      31     except (compat.FileNotFoundError, NoCredentialsError):
#
# ~/anaconda3/lib/python3.6/site-packages/fsspec/spec.py in open(self, path, mode, block_size, cache_options, **kwargs)
#     723                 cache_options=cache_options,
# --> 724                 **kwargs
#     725             )
#
# ~/anaconda3/lib/python3.6/site-packages/s3fs/core.py in _open(self, path, mode, block_size, acl, version_id, fill_cache, cache_type, autocommit, requester_pays, **kwargs)
#     314                       s3_additional_kwargs=kw, cache_type=cache_type,
# --> 315                       autocommit=autocommit, requester_pays=requester_pays)
#     316
#
# ~/anaconda3/lib/python3.6/site-packages/s3fs/core.py in __init__(self, s3, path, mode, block_size, acl, version_id, fill_cache, s3_additional_kwargs, autocommit, cache_type, requester_pays)
#     956         super().__init__(s3, path, mode, block_size, autocommit=autocommit,
# --> 957                          cache_type=cache_type)
#     958         self.s3 = self.fs  # compatibility
#
# ~/anaconda3/lib/python3.6/site-packages/fsspec/spec.py in __init__(self, fs, path, mode, block_size, autocommit, cache_type, cache_options, **kwargs)
#     955             if not hasattr(self, "details"):
# --> 956                 self.details = fs.info(path)
#     957             self.size = self.details["size"]
#
# ~/anaconda3/lib/python3.6/site-packages/s3fs/core.py in info(self, path, version_id)
#     485                 raise ValueError('Failed to head path %r: %s' % (path, e))
# --> 486         return super().info(path)
#     487
#
# ~/anaconda3/lib/python3.6/site-packages/fsspec/spec.py in info(self, path, **kwargs)
#     496         path = self._strip_protocol(path)
# --> 497         out = self.ls(self._parent(path), detail=True, **kwargs)
#     498         out = [o for o in out if o["name"].rstrip("/") == path]
#
# ~/anaconda3/lib/python3.6/site-packages/s3fs/core.py in ls(self, path, detail, refresh, **kwargs)
#     528         path = self._strip_protocol(path).rstrip('/')
# --> 529         files = self._ls(path, refresh=refresh)
#     530         if not files:
#
# ~/anaconda3/lib/python3.6/site-packages/s3fs/core.py in _ls(self, path, refresh)
#     425         else:
# --> 426             return self._lsdir(path, refresh)
#     427
#
# ~/anaconda3/lib/python3.6/site-packages/s3fs/core.py in _lsdir(self, path, refresh, max_items)
#     333                 dircache = []
# --> 334                 for i in it:
#     335                     dircache.extend(i.get('CommonPrefixes', []))
#
# ~/anaconda3/lib/python3.6/site-packages/botocore/paginate.py in __iter__(self)
#     254         while True:
# --> 255             response = self._make_request(current_kwargs)
#     256             parsed = self._extract_parsed_response(response)
#
# ~/anaconda3/lib/python3.6/site-packages/botocore/paginate.py in _make_request(self, current_kwargs)
#     331     def _make_request(self, current_kwargs):
# --> 332         return self._method(**current_kwargs)
#     333
#
# ~/anaconda3/lib/python3.6/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     356             # The "self" in this scope is referring to the BaseClient.
# --> 357             return self._make_api_call(operation_name, kwargs)
#     358
#
# ~/anaconda3/lib/python3.6/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     647             http, parsed_response = self._make_request(
# --> 648                 operation_model, request_dict, request_context)
#     649
#
# ~/anaconda3/lib/python3.6/site-packages/botocore/client.py in _make_request(self, operation_model, request_dict, request_context)
#     666         try:
# --> 667             return self._endpoint.make_request(operation_model, request_dict)
#     668         except Exception as e:
#
# ~/anaconda3/lib/python3.6/site-packages/botocore/endpoint.py in make_request(self, operation_model, request_dict)
#     101                      operation_model, request_dict)
# --> 102         return self._send_request(request_dict, operation_model)
#     103
#
# ~/anaconda3/lib/python3.6/site-packages/botocore/endpoint.py in _send_request(self, request_dict, operation_model)
#     131         attempts = 1
# --> 132         request = self.create_request(request_dict, operation_model)
#     133         context = request_dict['context']
#
# ~/anaconda3/lib/python3.6/site-packages/botocore/endpoint.py in create_request(self, params, operation_model)
#     115             self._event_emitter.emit(event_name, request=request,
# --> 116                                      operation_name=operation_model.name)
#     117         prepared_request = self.prepare_request(request)
#
# ~/anaconda3/lib/python3.6/site-packages/botocore/hooks.py in emit(self, event_name, **kwargs)
#     355         aliased_event_name = self._alias_event_name(event_name)
# --> 356         return self._emitter.emit(aliased_event_name, **kwargs)
#     357
#
# ~/anaconda3/lib/python3.6/site-packages/botocore/hooks.py in emit(self, event_name, **kwargs)
#     227         """
# --> 228         return self._emit(event_name, kwargs)
#     229
#
# ~/anaconda3/lib/python3.6/site-packages/botocore/hooks.py in _emit(self, event_name, kwargs, stop_on_response)
#     210             logger.debug('Event %s: calling handler %s', event_name, handler)
# --> 211             response = handler(**kwargs)
#     212             responses.append((handler, response))
#
# ~/anaconda3/lib/python3.6/site-packages/botocore/signers.py in handler(self, operation_name, request, **kwargs)
#      89         # Don't call this method directly.
# ---> 90         return self.sign(operation_name, request)
#      91
#
# ~/anaconda3/lib/python3.6/site-packages/botocore/signers.py in sign(self, operation_name, request, region_name, signing_type, expires_in, signing_name)
#     156
# --> 157             auth.add_auth(request)
#     158
#
# ~/anaconda3/lib/python3.6/site-packages/botocore/auth.py in add_auth(self, request)
#     424             'region', self._default_region_name)
# --> 425         super(S3SigV4Auth, self).add_auth(request)
#     426
#
# ~/anaconda3/lib/python3.6/site-packages/botocore/auth.py in add_auth(self, request)
#     356         if self.credentials is None:
# --> 357             raise NoCredentialsError
#     358         datetime_now = datetime.datetime.utcnow()
#
# NoCredentialsError: Unable to locate credentials
#
# During handling of the above exception, another exception occurred:
#
# ClientError                               Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/s3fs/core.py in _lsdir(self, path, refresh, max_items)
#     333                 dircache = []
# --> 334                 for i in it:
#     335                     dircache.extend(i.get('CommonPrefixes', []))
#
# ~/anaconda3/lib/python3.6/site-packages/botocore/paginate.py in __iter__(self)
#     254         while True:
# --> 255             response = self._make_request(current_kwargs)
#     256             parsed = self._extract_parsed_response(response)
#
# ~/anaconda3/lib/python3.6/site-packages/botocore/paginate.py in _make_request(self, current_kwargs)
#     331     def _make_request(self, current_kwargs):
# --> 332         return self._method(**current_kwargs)
#     333
#
# ~/anaconda3/lib/python3.6/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     356             # The "self" in this scope is referring to the BaseClient.
# --> 357             return self._make_api_call(operation_name, kwargs)
#     358
#
# ~/anaconda3/lib/python3.6/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     660             error_class = self.exceptions.from_code(error_code)
# --> 661             raise error_class(parsed_response, operation_name)
#     662         else:
#
# ClientError: An error occurred (AccessDenied) when calling the ListObjectsV2 operation: Access Denied
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# <ipython-input-4-d0f819fcef5c> in <module>
#       5
#       6 #read from csv (TODO change this file to updated version)
# ----> 7 df = pd.read_csv('s3a://bd-databricks-less-limited-shard-kjbhdfkljbnkjbdfkjbalkdnvubhbv/sequence_categoryok.csv')
#       8
#       9 columnlist = df.columns.tolist()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     411     compression = _infer_compression(filepath_or_buffer, compression)
#     412     filepath_or_buffer, _, compression, should_close = get_filepath_or_buffer(
# --> 413         filepath_or_buffer, encoding, compression)
#     414     kwds['compression'] = compression
#     415
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode)
#     214                                          encoding=encoding,
#     215                                          compression=compression,
# --> 216                                          mode=mode)
#     217
#     218     if is_gcs_url(filepath_or_buffer):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/s3.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode)
#      37         # for that bucket.
#      38         fs = s3fs.S3FileSystem(anon=True)
# ---> 39         filepath_or_buffer = fs.open(_strip_schema(filepath_or_buffer), mode)
#      40     return filepath_or_buffer, None, compression, True
#
# ~/anaconda3/lib/python3.6/site-packages/fsspec/spec.py in open(self, path, mode, block_size, cache_options, **kwargs)
#     722                 autocommit=ac,
#     723                 cache_options=cache_options,
# --> 724                 **kwargs
#     725             )
#     726             if not ac:
#
# ~/anaconda3/lib/python3.6/site-packages/s3fs/core.py in _open(self, path, mode, block_size, acl, version_id, fill_cache, cache_type, autocommit, requester_pays, **kwargs)
#     313                       version_id=version_id, fill_cache=fill_cache,
#     314                       s3_additional_kwargs=kw, cache_type=cache_type,
# --> 315                       autocommit=autocommit, requester_pays=requester_pays)
#     316
#     317     def _lsdir(self, path, refresh=False, max_items=None):
#
# ~/anaconda3/lib/python3.6/site-packages/s3fs/core.py in __init__(self, s3, path, mode, block_size, acl, version_id, fill_cache, s3_additional_kwargs, autocommit, cache_type, requester_pays)
#     955         self.req_kw = {'RequestPayer': 'requester'} if requester_pays else {}
#     956         super().__init__(s3, path, mode, block_size, autocommit=autocommit,
# --> 957                          cache_type=cache_type)
#     958         self.s3 = self.fs  # compatibility
#     959         if self.writable():
#
# ~/anaconda3/lib/python3.6/site-packages/fsspec/spec.py in __init__(self, fs, path, mode, block_size, autocommit, cache_type, cache_options, **kwargs)
#     954         if mode == "rb":
#     955             if not hasattr(self, "details"):
# --> 956                 self.details = fs.info(path)
#     957             self.size = self.details["size"]
#     958             self.cache = caches[cache_type](
#
# ~/anaconda3/lib/python3.6/site-packages/s3fs/core.py in info(self, path, version_id)
#     484             except ParamValidationError as e:
#     485                 raise ValueError('Failed to head path %r: %s' % (path, e))
# --> 486         return super().info(path)
#     487
#     488     def isdir(self, path):
#
# ~/anaconda3/lib/python3.6/site-packages/fsspec/spec.py in info(self, path, **kwargs)
#     495         """
#     496         path = self._strip_protocol(path)
# --> 497         out = self.ls(self._parent(path), detail=True, **kwargs)
#     498         out = [o for o in out if o["name"].rstrip("/") == path]
#     499         if out:
#
# ~/anaconda3/lib/python3.6/site-packages/s3fs/core.py in ls(self, path, detail, refresh, **kwargs)
#     527         """
#     528         path = self._strip_protocol(path).rstrip('/')
# --> 529         files = self._ls(path, refresh=refresh)
#     530         if not files:
#     531             files = self._ls(self._parent(path), refresh=refresh)
#
# ~/anaconda3/lib/python3.6/site-packages/s3fs/core.py in _ls(self, path, refresh)
#     424             return self._lsbuckets(refresh)
#     425         else:
# --> 426             return self._lsdir(path, refresh)
#     427
#     428     def exists(self, path):
#
# ~/anaconda3/lib/python3.6/site-packages/s3fs/core.py in _lsdir(self, path, refresh, max_items)
#     347                     f['name'] = f['Key']
#     348             except ClientError as e:
# --> 349                 raise translate_boto_error(e)
#     350
#     351             self.dircache[path] = files
#
# PermissionError: Access Denied

# %%
#delete rows with no tasks
xy = df[df.Tasks.notnull()]


#fill in Category, questions, field according to row above
xy['Category'].fillna(method='ffill', inplace=True)
xy['Questions'].fillna(method='ffill', inplace=True)   
xy['Field'].fillna(method='ffill', inplace=True) 


#reset index to contingent numbers after deleting rows with no tasks
xy.reset_index(drop=True, inplace=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.5/site-packages/pandas/core/generic.py:3295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# </div>

# %%
#record sequence of tasks
# group by (Category, Questions Field). If any one value changes, start new sequence from 1
index = [] #stores all sequence
i = 1
curr_category = xy['Category'][0]
curr_question = xy['Questions'][0]
curr_field = xy['Field'][0]

for j in range(len(xy)):
    c = xy['Category'][j]
    q = xy['Questions'][j]
    f = xy['Field'][j]
    
    if c != curr_category:
        i = 1
        curr_category = c
    if q != curr_question:
        i = 1
        curr_question = q
    if f != curr_field:
        i = 1
        curr_field = f
   
    index.append(i)
    i += 1
    
xy['Sequence'] = index #add sequence as a new column to visulize
xy
# Out:
# <div style="max-width:1500px;overflow:auto;">
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Category</th>
#       <th>Questions</th>
#       <th>Field</th>
#       <th>Tasks</th>
#       <th>Assignment</th>
#       <th>Visibility</th>
#       <th>Time</th>
#       <th>Min Time FORMULA</th>
#       <th>Budget</th>
#       <th>Sequence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>General</td>
#       <td>Wedding (Event) Date</td>
#       <td>text</td>
#       <td>Discuss wedding weekend events with client</td>
#       <td>Planner</td>
#       <td>Yes</td>
#       <td>7 months</td>
#       <td>5</td>
#       <td>NaN</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>General</td>
#       <td>Wedding (Event) Date</td>
#       <td>text</td>
#       <td>Register for gifts</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>7 months</td>
#       <td>5</td>
#       <td>NaN</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>General</td>
#       <td>Wedding (Event) Date</td>
#       <td>text</td>
#       <td>Obtain your marriage license</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>3 months</td>
#       <td>1</td>
#       <td>NaN</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>General</td>
#       <td>Wedding (Event) Date</td>
#       <td>text</td>
#       <td>Purchase gifts for wedding party, parents and ...</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>2 months</td>
#       <td>1</td>
#       <td>NaN</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>General</td>
#       <td>Guest Count</td>
#       <td>text</td>
#       <td>Compile Guest list</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>9 months</td>
#       <td>6</td>
#       <td>NaN</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>General</td>
#       <td>Guest Count</td>
#       <td>text</td>
#       <td>Collect Guest email and physical addresses</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>9 months</td>
#       <td>7</td>
#       <td>NaN</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>General</td>
#       <td>Guest Count</td>
#       <td>text</td>
#       <td>RSVP deadline</td>
#       <td>Planner</td>
#       <td>Yes</td>
#       <td>1 Month</td>
#       <td>1</td>
#       <td>NaN</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>General</td>
#       <td>Guest Count</td>
#       <td>text</td>
#       <td>Send Final Guest count to Planner</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>1 month</td>
#       <td>2 weeks</td>
#       <td>NaN</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>General</td>
#       <td>Guest Count</td>
#       <td>text</td>
#       <td>Update floor plan based on Final Guest count a...</td>
#       <td>Planner</td>
#       <td>No</td>
#       <td>4 weeks</td>
#       <td>4 weeks</td>
#       <td>NaN</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>General</td>
#       <td>Guest Count</td>
#       <td>text</td>
#       <td>Final table/seat assignments due</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>1 month</td>
#       <td>3 weeks</td>
#       <td>NaN</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>General</td>
#       <td>Guest Count</td>
#       <td>text</td>
#       <td>Update Contracts with Final Guest count</td>
#       <td>Planner</td>
#       <td>No</td>
#       <td>3 weeks</td>
#       <td>3 wks</td>
#       <td>NaN</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>General</td>
#       <td>Guest Count</td>
#       <td>text</td>
#       <td>Update Final payments (to reflect Final counts)</td>
#       <td>Planner</td>
#       <td>No</td>
#       <td>3 weeks</td>
#       <td>3 wks</td>
#       <td>NaN</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>General</td>
#       <td>Guest Count</td>
#       <td>text</td>
#       <td>Guest count contractually locked in</td>
#       <td>Planner</td>
#       <td>Yes</td>
#       <td>2 weeks</td>
#       <td>2 weeks</td>
#       <td>NaN</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>General</td>
#       <td>Budget</td>
#       <td>text</td>
#       <td>Determine budget</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>10 months</td>
#       <td>7</td>
#       <td>YES (total)</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>General</td>
#       <td>Budget</td>
#       <td>text</td>
#       <td>Draft a detailed budget to Determine spend</td>
#       <td>Planner</td>
#       <td>No</td>
#       <td>10 month</td>
#       <td>6</td>
#       <td>NaN</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>General</td>
#       <td>Budget</td>
#       <td>text</td>
#       <td>Review estimated event budget</td>
#       <td>Planner</td>
#       <td>Yes</td>
#       <td>9 months</td>
#       <td>7</td>
#       <td>NaN</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>General</td>
#       <td>WEBSITE:</td>
#       <td>text</td>
#       <td>Set up wedding website</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>9 months</td>
#       <td>6</td>
#       <td>NaN</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>General</td>
#       <td>WEBSITE:</td>
#       <td>text</td>
#       <td>Add date, wedding event location/time, and hot...</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>9 months</td>
#       <td>5</td>
#       <td>NaN</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>General</td>
#       <td>WEBSITE:</td>
#       <td>text</td>
#       <td>Send wedding website info (how to's)</td>
#       <td>Planner</td>
#       <td>No</td>
#       <td>9 months</td>
#       <td>6</td>
#       <td>NaN</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>General</td>
#       <td>WEBSITE:</td>
#       <td>text</td>
#       <td>Add transportation and additional event info t...</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>4 months</td>
#       <td>4</td>
#       <td>NaN</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>General</td>
#       <td>IG:</td>
#       <td>text</td>
#       <td>n/a</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>General</td>
#       <td>PINTEREST:</td>
#       <td>text</td>
#       <td>Share Pinterest Board and inspiration with Pla...</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>10 months</td>
#       <td>6</td>
#       <td>NaN</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>General</td>
#       <td>Is there a wedding party?</td>
#       <td>Yes</td>
#       <td>Send recommendations for wedding party attire</td>
#       <td>Planner</td>
#       <td>Yes</td>
#       <td>8 months</td>
#       <td>6</td>
#       <td>NaN</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>General</td>
#       <td>Is there a wedding party?</td>
#       <td>Yes</td>
#       <td>Book appointements/Shop for wedding party attire</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>7 months</td>
#       <td>6</td>
#       <td>NaN</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>General</td>
#       <td>Is there a wedding party?</td>
#       <td>Yes</td>
#       <td>Confirm delivery dates for wedding party attire</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>4 months</td>
#       <td>2</td>
#       <td>NaN</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>General</td>
#       <td>Is there a wedding party?</td>
#       <td>Yes</td>
#       <td>Send recommendations and sources for wedding p...</td>
#       <td>Planner</td>
#       <td>Yes</td>
#       <td>4 months</td>
#       <td>3</td>
#       <td>NaN</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>General</td>
#       <td>Is there a wedding party?</td>
#       <td>Yes</td>
#       <td>Order Bridesmaid dresses</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>6 months</td>
#       <td>5</td>
#       <td>NaN</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>27</th>

# %%
#assign columns to lists
category = [x for x in xy['Category']]
question = [x for x in xy['Questions']]
field = [x for x in xy['Field']]
description = xy['Tasks']
assignment = [x for x in xy['Assignment']]
visibility = [x for x in xy['Visibility']]
timing = [x for x in xy['Time']]
mintime = [x for x in xy['Min Time FORMULA']]
sequence = [x for x in xy['Sequence']]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#get rid of "-" in front of description
description = [x.replace("- ", "", 1) for x in description]
#get rid of " " after description
description = [x.strip() for x in description]


timing_new = []
mintime_new = []
#timing and mintime 
for i in range(len(timing)):
    
    #if Null value, keep as null
    if isinstance(timing[i], float) or isinstance(mintime[i], float):
        timing_new.append(None)
        mintime_new.append(None)
        continue
    
    
    #detect number for timing and mintime
    timing_num = int(''.join(filter(str.isdigit, timing[i])))
    mintime_num = int(''.join(filter(str.isdigit, mintime[i])))
    
    #detect starting alphabet (unit) for timing and mintime
    unit_timing= ''.join(filter(lambda x: x.isalpha(), timing[i]))[0]
    mintime_alpha = ''.join(filter(lambda x: x.isalpha(), mintime[i]))

    #if no units specified for mintime, default MONTH
    if mintime_alpha == '' or mintime_alpha[0] == 'm':
        unit_mintime = 'm'
    else:
        unit_mintime = mintime_alpha[0]
    
    #change all units to DAYS
    if unit_timing == 'm':
        timing_new.append(timing_num * 30)
    elif unit_timing == 'w':
        timing_new.append(timing_num * 7)
    else:
        timing_new.append(timing_num)
        
    if unit_mintime == 'm':
        mintime_new.append(mintime_num * 30)
    elif unit_mintime == 'w':
        mintime_new.append(mintime_num * 7)
    else:
        mintime_new.append(mintime_num)
       
    #negate for bubble computation
    timing_new[i] *= -1
    mintime_new[i] *= -1

            
print(timing_new)
print(mintime_new)

#for bubble computation
timingratio = [-x/300 for x in timing_new if x is not None]
        
#visibility
# for i, v in enumerate(visibility):
#     if v != 'yes':
#         visibility[i] = 'no'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[-210, -210, -90, -60, -270, -270, -1, -30, -28, -30, -21, -21, -14, -300, -300, -270, -270, -270, -270, -120, None, -300, -240, -210, -120, -120, -180, -150, -240, -210, -210, -150, -150, -240, -120, -180, -120, -60, -30, -210, -60, -300, -300, -300, -300, -300, -300, -300, -90, -120, -300, -300, -300, -300, -300, -270, -90, -120, -300, -300, -90, -60, -1, -240, -120, -120, -120, -60, -210, -120, -120, -60, -180, -270, -270, -270, -150, -90, -90, -30, -21, -150, -90, -90, -30, -21, -90, -90, -120, -270, -90, -120, -90, -180, -210, -120, -90, -150, None, -150, -150, -270, -270, -240, -90, -90, -30, -42, -30, -42, -30, -42, -300, -270, -270, -30, -270, -30, -240, -240, -240, -240, -180, -210, -210, -240, -240, -210, -240, -2250, -210, -180, -210, -210, -180, -180, -150, -120, -120, -120, -750, -120, -120, -90, -63, -90, -60, -30, -28, -4, -210, -180, -150, -180, -180, -180, -180, -150, -180, -180, -150, -180, -180, -150, -240, -270, -270, -90, -210, -1950, -3, -210, -1950, -3, -150, -150, -150, -210, -210, -240, -240, -240, -210, -90, -150, -150, -120, -120, -120, -90, -30, None, -240, -270, -210, -60, -42, -14, -21, -90, -14, -3, -1]
# [-150, -150, -30, -30, -180, -210, -30, -14, -28, -21, -21, -21, -14, -210, -180, -210, -180, -150, -180, -120, None, -180, -180, -180, -60, -90, -150, -90, -180, -180, -180, -120, -90, -90, -60, -90, -180, -30, -30, -180, -60, -180, -180, -180, -180, -150, -150, -180, -60, -60, -180, -180, -180, -150, -150, -180, -60, -60, -180, -180, -60, -60, -1, -150, -60, -90, -90, -60, -150, -90, -90, -60, -150, -180, -180, -180, -120, -90, -60, -21, -14, -120, -90, -60, -21, -14, -90, -60, -60, -210, -60, -60, -60, -90, -150, -120, -120, -90, None, -30, -30, -150, -150, -150, -60, -60, -30, -30, -30, -30, -30, -30, -180, -180, -180, -30, -180, -30, -150, -150, -150, -150, -120, -150, -150, -150, -150, -150, -120, -120, -120, -90, -210, -180, -150, -150, -90, -90, -90, -90, -60, -90, -90, -60, -42, -60, -60, -21, -20, -4, -120, -120, -120, -120, -120, -120, -120, -90, -120, -120, -120, -120, -120, -90, -120, -180, -180, -30, -150, -150, -3, -150, -150, -3, -90, -90, -90, -150, -120, -150, -150, -150, -120, -90, -60, -60, -60, -90, -90, -90, -7, None, -150, -210, -150, -30, -30, -7, -7, -60, -7, -3, -1]
# </div>

# %%
xy["newtime"] = timing_new
xy["newmin"] = mintime_new

newtime = [x for x in xy['newtime']]
newmin = [x for x in xy['newmin']]

xy
# Out:
# <div style="max-width:1500px;overflow:auto;">
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Category</th>
#       <th>Questions</th>
#       <th>Field</th>
#       <th>Tasks</th>
#       <th>Assignment</th>
#       <th>Visibility</th>
#       <th>Time</th>
#       <th>Min Time FORMULA</th>
#       <th>Budget</th>
#       <th>Sequence</th>
#       <th>newtime</th>
#       <th>newmin</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>General</td>
#       <td>Wedding (Event) Date</td>
#       <td>text</td>
#       <td>Discuss wedding weekend events with client</td>
#       <td>Planner</td>
#       <td>Yes</td>
#       <td>7 months</td>
#       <td>5</td>
#       <td>NaN</td>
#       <td>1</td>
#       <td>-210.0</td>
#       <td>-150.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>General</td>
#       <td>Wedding (Event) Date</td>
#       <td>text</td>
#       <td>Register for gifts</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>7 months</td>
#       <td>5</td>
#       <td>NaN</td>
#       <td>2</td>
#       <td>-210.0</td>
#       <td>-150.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>General</td>
#       <td>Wedding (Event) Date</td>
#       <td>text</td>
#       <td>Obtain your marriage license</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>3 months</td>
#       <td>1</td>
#       <td>NaN</td>
#       <td>3</td>
#       <td>-90.0</td>
#       <td>-30.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>General</td>
#       <td>Wedding (Event) Date</td>
#       <td>text</td>
#       <td>Purchase gifts for wedding party, parents and ...</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>2 months</td>
#       <td>1</td>
#       <td>NaN</td>
#       <td>4</td>
#       <td>-60.0</td>
#       <td>-30.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>General</td>
#       <td>Guest Count</td>
#       <td>text</td>
#       <td>Compile Guest list</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>9 months</td>
#       <td>6</td>
#       <td>NaN</td>
#       <td>1</td>
#       <td>-270.0</td>
#       <td>-180.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>General</td>
#       <td>Guest Count</td>
#       <td>text</td>
#       <td>Collect Guest email and physical addresses</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>9 months</td>
#       <td>7</td>
#       <td>NaN</td>
#       <td>2</td>
#       <td>-270.0</td>
#       <td>-210.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>General</td>
#       <td>Guest Count</td>
#       <td>text</td>
#       <td>RSVP deadline</td>
#       <td>Planner</td>
#       <td>Yes</td>
#       <td>1 Month</td>
#       <td>1</td>
#       <td>NaN</td>
#       <td>3</td>
#       <td>-1.0</td>
#       <td>-30.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>General</td>
#       <td>Guest Count</td>
#       <td>text</td>
#       <td>Send Final Guest count to Planner</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>1 month</td>
#       <td>2 weeks</td>
#       <td>NaN</td>
#       <td>4</td>
#       <td>-30.0</td>
#       <td>-14.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>General</td>
#       <td>Guest Count</td>
#       <td>text</td>
#       <td>Update floor plan based on Final Guest count a...</td>
#       <td>Planner</td>
#       <td>No</td>
#       <td>4 weeks</td>
#       <td>4 weeks</td>
#       <td>NaN</td>
#       <td>5</td>
#       <td>-28.0</td>
#       <td>-28.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>General</td>
#       <td>Guest Count</td>
#       <td>text</td>
#       <td>Final table/seat assignments due</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>1 month</td>
#       <td>3 weeks</td>
#       <td>NaN</td>
#       <td>6</td>
#       <td>-30.0</td>
#       <td>-21.0</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>General</td>
#       <td>Guest Count</td>
#       <td>text</td>
#       <td>Update Contracts with Final Guest count</td>
#       <td>Planner</td>
#       <td>No</td>
#       <td>3 weeks</td>
#       <td>3 wks</td>
#       <td>NaN</td>
#       <td>7</td>
#       <td>-21.0</td>
#       <td>-21.0</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>General</td>
#       <td>Guest Count</td>
#       <td>text</td>
#       <td>Update Final payments (to reflect Final counts)</td>
#       <td>Planner</td>
#       <td>No</td>
#       <td>3 weeks</td>
#       <td>3 wks</td>
#       <td>NaN</td>
#       <td>8</td>
#       <td>-21.0</td>
#       <td>-21.0</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>General</td>
#       <td>Guest Count</td>
#       <td>text</td>
#       <td>Guest count contractually locked in</td>
#       <td>Planner</td>
#       <td>Yes</td>
#       <td>2 weeks</td>
#       <td>2 weeks</td>
#       <td>NaN</td>
#       <td>9</td>
#       <td>-14.0</td>
#       <td>-14.0</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>General</td>
#       <td>Budget</td>
#       <td>text</td>
#       <td>Determine budget</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>10 months</td>
#       <td>7</td>
#       <td>YES (total)</td>
#       <td>1</td>
#       <td>-300.0</td>
#       <td>-210.0</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>General</td>
#       <td>Budget</td>
#       <td>text</td>
#       <td>Draft a detailed budget to Determine spend</td>
#       <td>Planner</td>
#       <td>No</td>
#       <td>10 month</td>
#       <td>6</td>
#       <td>NaN</td>
#       <td>2</td>
#       <td>-300.0</td>
#       <td>-180.0</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>General</td>
#       <td>Budget</td>
#       <td>text</td>
#       <td>Review estimated event budget</td>
#       <td>Planner</td>
#       <td>Yes</td>
#       <td>9 months</td>
#       <td>7</td>
#       <td>NaN</td>
#       <td>3</td>
#       <td>-270.0</td>
#       <td>-210.0</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>General</td>
#       <td>WEBSITE:</td>
#       <td>text</td>
#       <td>Set up wedding website</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>9 months</td>
#       <td>6</td>
#       <td>NaN</td>
#       <td>1</td>
#       <td>-270.0</td>
#       <td>-180.0</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>General</td>
#       <td>WEBSITE:</td>
#       <td>text</td>
#       <td>Add date, wedding event location/time, and hot...</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>9 months</td>
#       <td>5</td>
#       <td>NaN</td>
#       <td>2</td>
#       <td>-270.0</td>
#       <td>-150.0</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>General</td>
#       <td>WEBSITE:</td>
#       <td>text</td>
#       <td>Send wedding website info (how to's)</td>
#       <td>Planner</td>
#       <td>No</td>
#       <td>9 months</td>
#       <td>6</td>
#       <td>NaN</td>
#       <td>3</td>
#       <td>-270.0</td>
#       <td>-180.0</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>General</td>
#       <td>WEBSITE:</td>
#       <td>text</td>
#       <td>Add transportation and additional event info t...</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>4 months</td>
#       <td>4</td>
#       <td>NaN</td>
#       <td>4</td>
#       <td>-120.0</td>
#       <td>-120.0</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>General</td>
#       <td>IG:</td>
#       <td>text</td>
#       <td>n/a</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>1</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>General</td>
#       <td>PINTEREST:</td>
#       <td>text</td>
#       <td>Share Pinterest Board and inspiration with Pla...</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>10 months</td>
#       <td>6</td>
#       <td>NaN</td>
#       <td>1</td>
#       <td>-300.0</td>
#       <td>-180.0</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>General</td>
#       <td>Is there a wedding party?</td>
#       <td>Yes</td>
#       <td>Send recommendations for wedding party attire</td>
#       <td>Planner</td>
#       <td>Yes</td>
#       <td>8 months</td>
#       <td>6</td>
#       <td>NaN</td>
#       <td>1</td>
#       <td>-240.0</td>
#       <td>-180.0</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>General</td>
#       <td>Is there a wedding party?</td>
#       <td>Yes</td>
#       <td>Book appointements/Shop for wedding party attire</td>
#       <td>Cl

# %%
# Calling DataFrame constructor after zipping all lists

#can also do xy["newmin"] = mintime_new for example to make change in-place 
#instead of creating new df
df = pd.DataFrame(list(zip(description, question, field, timing, timingratio, mintime, assignment, visibility, category, sequence,newtime,newmin)), 
               columns =['description', 'question', 'field', 'timing', 'timingratio', 'mintime', 'assignment', 'visibility', 'category', 'sequence','newtime','newmin']) 
df
# Out:
# <div style="max-width:1500px;overflow:auto;">
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>description</th>
#       <th>question</th>
#       <th>field</th>
#       <th>timing</th>
#       <th>timingratio</th>
#       <th>mintime</th>
#       <th>assignment</th>
#       <th>visibility</th>
#       <th>category</th>
#       <th>sequence</th>
#       <th>newtime</th>
#       <th>newmin</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Discuss wedding weekend events with client</td>
#       <td>Wedding (Event) Date</td>
#       <td>text</td>
#       <td>7 months</td>
#       <td>0.700000</td>
#       <td>5</td>
#       <td>Planner</td>
#       <td>Yes</td>
#       <td>General</td>
#       <td>1</td>
#       <td>-210.0</td>
#       <td>-150.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Register for gifts</td>
#       <td>Wedding (Event) Date</td>
#       <td>text</td>
#       <td>7 months</td>
#       <td>0.700000</td>
#       <td>5</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>General</td>
#       <td>2</td>
#       <td>-210.0</td>
#       <td>-150.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Obtain your marriage license</td>
#       <td>Wedding (Event) Date</td>
#       <td>text</td>
#       <td>3 months</td>
#       <td>0.300000</td>
#       <td>1</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>General</td>
#       <td>3</td>
#       <td>-90.0</td>
#       <td>-30.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Purchase gifts for wedding party, parents and ...</td>
#       <td>Wedding (Event) Date</td>
#       <td>text</td>
#       <td>2 months</td>
#       <td>0.200000</td>
#       <td>1</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>General</td>
#       <td>4</td>
#       <td>-60.0</td>
#       <td>-30.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Compile Guest list</td>
#       <td>Guest Count</td>
#       <td>text</td>
#       <td>9 months</td>
#       <td>0.900000</td>
#       <td>6</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>General</td>
#       <td>1</td>
#       <td>-270.0</td>
#       <td>-180.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Collect Guest email and physical addresses</td>
#       <td>Guest Count</td>
#       <td>text</td>
#       <td>9 months</td>
#       <td>0.900000</td>
#       <td>7</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>General</td>
#       <td>2</td>
#       <td>-270.0</td>
#       <td>-210.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>RSVP deadline</td>
#       <td>Guest Count</td>
#       <td>text</td>
#       <td>1 Month</td>
#       <td>0.003333</td>
#       <td>1</td>
#       <td>Planner</td>
#       <td>Yes</td>
#       <td>General</td>
#       <td>3</td>
#       <td>-1.0</td>
#       <td>-30.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Send Final Guest count to Planner</td>
#       <td>Guest Count</td>
#       <td>text</td>
#       <td>1 month</td>
#       <td>0.100000</td>
#       <td>2 weeks</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>General</td>
#       <td>4</td>
#       <td>-30.0</td>
#       <td>-14.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Update floor plan based on Final Guest count a...</td>
#       <td>Guest Count</td>
#       <td>text</td>
#       <td>4 weeks</td>
#       <td>0.093333</td>
#       <td>4 weeks</td>
#       <td>Planner</td>
#       <td>No</td>
#       <td>General</td>
#       <td>5</td>
#       <td>-28.0</td>
#       <td>-28.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Final table/seat assignments due</td>
#       <td>Guest Count</td>
#       <td>text</td>
#       <td>1 month</td>
#       <td>0.100000</td>
#       <td>3 weeks</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>General</td>
#       <td>6</td>
#       <td>-30.0</td>
#       <td>-21.0</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Update Contracts with Final Guest count</td>
#       <td>Guest Count</td>
#       <td>text</td>
#       <td>3 weeks</td>
#       <td>0.070000</td>
#       <td>3 wks</td>
#       <td>Planner</td>
#       <td>No</td>
#       <td>General</td>
#       <td>7</td>
#       <td>-21.0</td>
#       <td>-21.0</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Update Final payments (to reflect Final counts)</td>
#       <td>Guest Count</td>
#       <td>text</td>
#       <td>3 weeks</td>
#       <td>0.070000</td>
#       <td>3 wks</td>
#       <td>Planner</td>
#       <td>No</td>
#       <td>General</td>
#       <td>8</td>
#       <td>-21.0</td>
#       <td>-21.0</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Guest count contractually locked in</td>
#       <td>Guest Count</td>
#       <td>text</td>
#       <td>2 weeks</td>
#       <td>0.046667</td>
#       <td>2 weeks</td>
#       <td>Planner</td>
#       <td>Yes</td>
#       <td>General</td>
#       <td>9</td>
#       <td>-14.0</td>
#       <td>-14.0</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Determine budget</td>
#       <td>Budget</td>
#       <td>text</td>
#       <td>10 months</td>
#       <td>1.000000</td>
#       <td>7</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>General</td>
#       <td>1</td>
#       <td>-300.0</td>
#       <td>-210.0</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Draft a detailed budget to Determine spend</td>
#       <td>Budget</td>
#       <td>text</td>
#       <td>10 month</td>
#       <td>1.000000</td>
#       <td>6</td>
#       <td>Planner</td>
#       <td>No</td>
#       <td>General</td>
#       <td>2</td>
#       <td>-300.0</td>
#       <td>-180.0</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Review estimated event budget</td>
#       <td>Budget</td>
#       <td>text</td>
#       <td>9 months</td>
#       <td>0.900000</td>
#       <td>7</td>
#       <td>Planner</td>
#       <td>Yes</td>
#       <td>General</td>
#       <td>3</td>
#       <td>-270.0</td>
#       <td>-210.0</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Set up wedding website</td>
#       <td>WEBSITE:</td>
#       <td>text</td>
#       <td>9 months</td>
#       <td>0.900000</td>
#       <td>6</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>General</td>
#       <td>1</td>
#       <td>-270.0</td>
#       <td>-180.0</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Add date, wedding event location/time, and hot...</td>
#       <td>WEBSITE:</td>
#       <td>text</td>
#       <td>9 months</td>
#       <td>0.900000</td>
#       <td>5</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>General</td>
#       <td>2</td>
#       <td>-270.0</td>
#       <td>-150.0</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Send wedding website info (how to's)</td>
#       <td>WEBSITE:</td>
#       <td>text</td>
#       <td>9 months</td>
#       <td>0.900000</td>
#       <td>6</td>
#       <td>Planner</td>
#       <td>No</td>
#       <td>General</td>
#       <td>3</td>
#       <td>-270.0</td>
#       <td>-180.0</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Add transportation and additional event info t...</td>
#       <td>WEBSITE:</td>
#       <td>text</td>
#       <td>4 months</td>
#       <td>0.400000</td>
#       <td>4</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>General</td>
#       <td>4</td>
#       <td>-120.0</td>
#       <td>-120.0</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>n/a</td>
#       <td>IG:</td>
#       <td>text</td>
#       <td>NaN</td>
#       <td>1.000000</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>General</td>
#       <td>1</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>Share Pinterest Board and inspiration with Pla...</td>
#       <td>PINTEREST:</td>
#       <td>text</td>
#       <td>10 months</td>
#       <td>0.800000</td>
#       <td>6</td>
#       <td>Client</td>
#       <td>Yes</td>
#       <td>General</td>
#       <td>1</td>
#       <td>-300.0</td>
#       <td>-180.0</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>Send recommendations for wedding party attire</td>
#       <td>Is there a wedding party?</td>
#       <td>Yes</td>
#       <td>8 months</td>
#       <td>0.700000</td>
#       <td>6</td>
#       <td>Planner</td>
#       <td>Yes</td>
#       <td>General</td>
#       <td>1</td>
#       <td>-240.0</td>
#       <td>-180.0</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>Book appointements/Shop for wedding par

# %%
import numpy as np
import pandas as pd

# Enable Arrow-based columnar data transfers
spark.conf.set("spark.sql.execution.arrow.enabled", "true")

# Create a Spark DataFrame from a Pandas DataFrame using Arrow
sdf = spark.createDataFrame(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(sdf)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>description</th><th>question</th><th>field</th><th>timing</th><th>timingratio</th><th>mintime</th><th>assignment</th><th>visibility</th><th>category</th><th>sequence</th><th>newtime</th><th>newmin</th></tr></thead><tbody><tr><td>Discuss wedding weekend events with client</td><td>Wedding (Event) Date</td><td>text</td><td>7 months</td><td>0.7</td><td>5</td><td>Planner</td><td>Yes</td><td>General</td><td>1</td><td>-210.0</td><td>-150.0</td></tr><tr><td>Register for gifts</td><td>Wedding (Event) Date</td><td>text</td><td>7 months</td><td>0.7</td><td>5</td><td>Client</td><td>Yes</td><td>General</td><td>2</td><td>-210.0</td><td>-150.0</td></tr><tr><td>Obtain your marriage license</td><td>Wedding (Event) Date</td><td>text</td><td>3 months</td><td>0.3</td><td>1</td><td>Client</td><td>Yes</td><td>General</td><td>3</td><td>-90.0</td><td>-30.0</td></tr><tr><td>Purchase gifts for wedding party, parents and each other</td><td>Wedding (Event) Date</td><td>text</td><td>2 months</td><td>0.2</td><td>1</td><td>Client</td><td>Yes</td><td>General</td><td>4</td><td>-60.0</td><td>-30.0</td></tr><tr><td>Compile Guest list</td><td>Guest Count</td><td>text</td><td>9 months</td><td>0.9</td><td>6</td><td>Client</td><td>Yes</td><td>General</td><td>1</td><td>-270.0</td><td>-180.0</td></tr><tr><td>Collect Guest email and physical addresses</td><td>Guest Count</td><td>text</td><td>9 months</td><td>0.9</td><td>7</td><td>Client</td><td>Yes</td><td>General</td><td>2</td><td>-270.0</td><td>-210.0</td></tr><tr><td>RSVP deadline</td><td>Guest Count</td><td>text</td><td>1 Month</td><td>0.0033333333333333335</td><td>1</td><td>Planner</td><td>Yes</td><td>General</td><td>3</td><td>-1.0</td><td>-30.0</td></tr><tr><td>Send Final Guest count to Planner</td><td>Guest Count</td><td>text</td><td>1 month</td><td>0.1</td><td>2 weeks</td><td>Client</td><td>Yes</td><td>General</td><td>4</td><td>-30.0</td><td>-14.0</td></tr><tr><td>Update floor plan based on Final Guest count and Send to client for table/seat assignments</td><td>Guest Count</td><td>text</td><td>4 weeks</td><td>0.09333333333333334</td><td>4 weeks</td><td>Planner</td><td>No</td><td>General</td><td>5</td><td>-28.0</td><td>-28.0</td></tr><tr><td>Final table/seat assignments due</td><td>Guest Count</td><td>text</td><td>1 month</td><td>0.1</td><td>3 weeks</td><td>Client</td><td>Yes</td><td>General</td><td>6</td><td>-30.0</td><td>-21.0</td></tr><tr><td>Update Contracts with Final Guest count</td><td>Guest Count</td><td>text</td><td>3 weeks </td><td>0.07</td><td>3 wks</td><td>Planner</td><td>No</td><td>General</td><td>7</td><td>-21.0</td><td>-21.0</td></tr><tr><td>Update Final payments (to reflect Final counts)</td><td>Guest Count</td><td>text</td><td>3 weeks</td><td>0.07</td><td>3 wks</td><td>Planner</td><td>No</td><td>General</td><td>8</td><td>-21.0</td><td>-21.0</td></tr><tr><td>Guest count contractually locked in</td><td>Guest Count</td><td>text</td><td>2 weeks</td><td>0.04666666666666667</td><td>2 weeks</td><td>Planner</td><td>Yes</td><td>General</td><td>9</td><td>-14.0</td><td>-14.0</td></tr><tr><td>Determine budget</td><td>Budget</td><td>text</td><td>10 months</td><td>1.0</td><td>7</td><td>Client</td><td>Yes</td><td>General</td><td>1</td><td>-300.0</td><td>-210.0</td></tr><tr><td>Draft a detailed budget to Determine spend</td><td>Budget</td><td>text</td><td>10 month</td><td>1.0</td><td>6</td><td>Planner</td><td>No</td><td>General</td><td>2</td><td>-300.0</td><td>-180.0</td></tr><tr><td>Review estimated event budget</td><td>Budget</td><td>text</td><td>9 months</td><td>0.9</td><td>7</td><td>Planner</td><td>Yes</td><td>General</td><td>3</td><td>-270.0</td><td>-210.0</td></tr><tr><td>Set up wedding website</td><td>WEBSITE:</td><td>text</td><td>9 months</td><td>0.9</td><td>6</td><td>Client</td><td>Yes</td><td>General</td><td>1</td><td>-270.0</td><td>-180.0</td></tr><tr><td>Add date, wedding event loc ...

# %%
sdf.coalesce(1).write.option("header", "true").csv("s3://bd-databricks-less-limited-shard-kjbhdfkljbnkjbdfkjbalkdnvubhbv/testoutput4.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
